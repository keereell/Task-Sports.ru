# %% [markdown]
# # ÐÐ°Ð´Ð°ÑÐ° #
#
# ÐÑÐ¾Ð°Ð½Ð°Ð»Ð¸Ð·Ð¸ÑÐ¾Ð²Ð°ÑÑ Ð¼Ð°ÑÑÐ¸Ð² Ð´Ð°Ð½Ð½ÑÑ (http://archive.ics.uci.edu/ml/datasets/Facebook+metrics) Ð¿ÑÐ¸ Ð¿Ð¾Ð¼Ð¾ÑÐ¸ ÑÐ·ÑÐºÐ° Python (Ð´Ð¾Ð¿ÑÑÐºÐ°ÐµÑÑÑ Ð¸ ÑÐµÐºÐ¾Ð¼ÐµÐ½Ð´ÑÐµÑÑÑ Ð¸ÑÐ¿Ð¾Ð»ÑÐ·Ð¾Ð²Ð°Ð½Ð¸Ðµ Ð´Ð¾Ð¿Ð¾Ð»Ð½Ð¸ÑÐµÐ»ÑÐ½ÑÑ Ð±Ð¸Ð±Ð»Ð¸Ð¾ÑÐµÐº): Ð²ÑÑÐ¸ÑÐ»ÐµÐ½Ð¸Ðµ ÑÑÐµÐ´Ð½ÐµÐ³Ð¾, Ð¼Ð°ÐºÑÐ¸Ð¼Ð°Ð»ÑÐ½Ð¾Ð³Ð¾/Ð¼Ð¸Ð½Ð¸Ð¼Ð°Ð»ÑÐ½Ð¾Ð³Ð¾ Ð·Ð½Ð°ÑÐµÐ½Ð¸Ð¹, Ð¼ÐµÐ´Ð¸Ð°Ð½Ñ, Ð¼Ð¾Ð´Ñ ÑÐ¸ÑÐ»Ð¾Ð²ÑÑ Ð·Ð½Ð°ÑÐµÐ½Ð¸Ð¹ ÐºÐ°Ðº Ð´Ð»Ñ Ð²ÑÐµÐ³Ð¾ Ð¼Ð°ÑÑÐ¸Ð²Ð° Ð² ÑÐµÐ»Ð¾Ð¼, ÑÐ°Ðº Ð¸ Ð´Ð»Ñ ÐºÐ°Ð¶Ð´Ð¾Ð³Ð¾ ÑÐ¸Ð¿Ð° ÐºÐ¾Ð½ÑÐµÐ½ÑÐ° (ÑÑÐ¾Ð»Ð±ÐµÑ Type) Ð² Ð¾ÑÐ´ÐµÐ»ÑÐ½Ð¾ÑÑÐ¸. ÐÐ°Ð¹ÑÐ¸ ÑÐ°Ð¼ÑÐ¹ Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½ÑÐ¹ Ð¾Ð±ÑÐµÐºÑ Ð² Ð²ÑÐ±Ð¾ÑÐºÐµ, Ð¾Ð±ÑÑÑÐ½Ð¸ÑÑ Ð¿Ð¾ÑÐµÐ¼Ñ. Ð ÐµÑÐµÐ½Ð¸Ðµ Ð¿ÑÐµÐ´Ð¾ÑÑÐ°Ð²Ð¸ÑÑ Ð² Ð²Ð¸Ð´Ðµ .py/.ipynb ÑÐ°Ð¹Ð»Ð°.

# %%
# Python 2 and 3 compatibility
from __future__ import (absolute_import, division,
                        print_function, unicode_literals)
# Ð¾ÑÐºÐ»ÑÑÐ¸Ð¼ Ð¿ÑÐµÐ´ÑÐ¿ÑÐµÐ¶Ð´ÐµÐ½Ð¸Ñ Anaconda
import warnings
warnings.simplefilter('ignore')
import pandas as pd
# %pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # ÐÐ°Ð³ÑÑÐ¶Ð°ÐµÐ¼ Ð¸ Ð¸Ð·ÑÑÐ°ÐµÐ¼ Ð´Ð°Ð½Ð½ÑÐµ

# %%
df = pd.read_csv('dataset_Facebook.csv', delimiter=';')
df.shape
# Out:
# (500, 19)

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Ð²ÑÑÐ¸ÑÐ»ÐµÐ½Ð¸Ðµ ÑÑÐµÐ´Ð½ÐµÐ³Ð¾, Ð¼Ð°ÐºÑÐ¸Ð¼Ð°Ð»ÑÐ½Ð¾Ð³Ð¾/Ð¼Ð¸Ð½Ð¸Ð¼Ð°Ð»ÑÐ½Ð¾Ð³Ð¾ Ð·Ð½Ð°ÑÐµÐ½Ð¸Ð¹, Ð¼ÐµÐ´Ð¸Ð°Ð½Ñ, Ð¼Ð¾Ð´Ñ

# %% [markdown]
# # - Ð´Ð»Ñ Ð²ÑÐµÐ³Ð¾ Ð¼Ð°ÑÑÐ¸Ð²Ð° Ð² ÑÐµÐ»Ð¾Ð¼

# %%
modes = df.mode().drop('Type', axis=1).iloc[0]

# %%
df.describe(percentiles=[]).drop(['count', 'std'], axis=0).append(modes).rename(index={"50%": "median", 0: "mode"})
# Out:
#         Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# mean          123194.176      1.88       7.038          4.15       7.84
# min            81370.000      1.00       1.000          1.00       1.00
# median        129600.000      2.00       7.000          4.00       9.00
# max           139441.000      3.00      12.000          7.00      23.00
# mode          136393.000      1.00      10.000          7.00       3.00
#
#             Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# mean    0.278557                   13903.36                        29585.948
# min     0.000000                     238.00                          570.000
# median  0.000000                    5281.00                         9051.000
# max     1.000000                  180480.00                      1110282.000
# mode    0.000000                     677.00                         4372.000
#
#         Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# # - Ð´Ð»Ñ ÐºÐ°Ð¶Ð´Ð¾Ð³Ð¾ ÑÐ¸Ð¿Ð° ÐºÐ¾Ð½ÑÐµÐ½ÑÐ° Ð² Ð¾ÑÐ´ÐµÐ»ÑÐ½Ð¾ÑÑÐ¸

# %%
list(df['Type'].value_counts().index)
# Out:
# ['Photo', 'Status', 'Link', 'Video']

# %%
def ByType(type_):
    modes = df[df['Type']==type_].mode().drop('Type', axis=1).iloc[0]
    return df[df['Type']==type_].describe(percentiles=[]).drop(['count', 'std'], axis=0).append(modes).rename(index={"50%": "median", 0: "mode"})

# %%
ByType('Photo')
# Out:
#         Page total likes  Category  Post Month  Post Weekday  Post Hour  Paid  \
# mean       122354.171362   1.91784    6.805164      4.107981   7.997653  0.28
# min         81370.000000   1.00000    1.000000      1.000000   1.000000  0.00
# median     128032.000000   2.00000    7.000000      4.000000   9.000000  0.00
# max        139441.000000   3.00000   12.000000      7.000000  23.000000  1.00
# mode       124940.000000   1.00000   10.000000      7.000000   3.000000  0.00
#
#         Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# mean                 13137.814554                     2.899450e+04
# min                    238.000000                     5.700000e+02
# median                4675.000000                     8.118500e+03
# max                 180480.000000                     1.110282e+06
# mode                   677.000000                     4.372000e+03
#
#         Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
ByType('Status')
# Out:
#         Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# mean       132647.044444  2.022222    9.066667      4.577778   7.244444
# min        104070.000000  1.000000    3.000000      1.000000   2.000000
# median     135713.000000  2.000000   10.000000      5.000000   9.000000
# max        139441.000000  3.000000   12.000000      7.000000  15.000000
# mode       139441.000000  2.000000   12.000000      5.000000  10.000000
#
#             Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# mean    0.222222               13078.888889                     24244.466667
# min     0.000000                3930.000000                      7509.000000
# median  0.000000               11096.000000                     20849.000000
# max     1.000000               31136.000000                     59964.000000
# mode    0.000000                        NaN                              NaN
#
#         Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
ByType('Link')
# Out:
#         Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# mean       116363.181818  1.136364    6.590909      4.272727   5.727273
# min         85979.000000  1.000000    1.000000      1.000000   2.000000
# median     115396.000000  1.000000    4.500000      4.500000   4.000000
# max        138895.000000  3.000000   12.000000      7.000000  14.000000
# mode       138353.000000  1.000000   12.000000      6.000000   3.000000
#
#             Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# mean    0.272727               18544.590909                     28725.454545
# min     0.000000                1536.000000                      3094.000000
# median  0.000000                7422.000000                      9773.000000
# max     1.000000               70912.000000                    229733.000000
# mode    0.000000                        NaN                              NaN
#
#         Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
ByType('Video')
# Out:
#         Page total likes  Category  Post Month  Post Weekday  Post Hour  \
# mean       135014.857143       1.0    9.571429      3.571429   8.714286
# min        126424.000000       1.0    6.000000      2.000000   2.000000
# median     137893.000000       1.0   11.000000      3.000000  11.000000
# max        138895.000000       1.0   12.000000      6.000000  13.000000
# mode       137893.000000       1.0   11.000000      2.000000  11.000000
#
#             Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# mean    0.571429               51205.714286                    102622.428571
# min     0.000000               13544.000000                     30235.000000
# median  1.000000               30624.000000                     56950.000000
# max     1.000000              139008.000000                    277100.000000
# mode    1.000000                        NaN                              NaN
#
#         Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# # ÐÐ°Ð¹ÑÐ¸ ÑÐ°Ð¼ÑÐ¹ Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½ÑÐ¹ Ð¾Ð±ÑÐµÐºÑ Ð² Ð²ÑÐ±Ð¾ÑÐºÐµ, Ð¾Ð±ÑÑÑÐ½Ð¸ÑÑ Ð¿Ð¾ÑÐµÐ¼Ñ.

# %% [markdown]
# ### ÐÐ¾ ÐºÐ°ÐºÐ¾Ð¼Ñ Ð¿Ð°ÑÐ°Ð¼ÐµÑÑÑ Ð¾Ð¿ÑÐµÐ´ÐµÐ»ÑÑÑ Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½Ð¾ÑÑÑ?

# %%
popular = ['comment', 'like', 'share', 'Total Interactions']

# %%
df[popular].max()
# Out:
# comment                372.0
# like                  5172.0
# share                  790.0
# Total Interactions    6334.0
# dtype: float64

# %% [markdown]
# ÐÐ¾ÑÐ¾Ð¶Ðµ, ÑÑÐ¾
#
# 'Total Interactions' = 'comment' + 'like' + 'share'
#
# Ð¿ÑÐ¾Ð²ÐµÑÐ¸Ð¼

# %%
check = df['Total Interactions'] - df['comment'] - df['like'] - df['share']
print(check.min())
print(check.max())
# Out:
# 0.0
# 0.0

# %% [markdown]
# ### ÐÑÐµÐ¼ Ð»Ð¸Ð´ÐµÑÐ° Ð¿Ð¾ 'Total Interactions' ###

# %%
df[df['Total Interactions'] == df['Total Interactions'].max()]
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 244                    8072                     4010
#
#      Lifetime Post Consumptions  \
# 244                        6242
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 244                                             108752
#
#      Lifetime Post reach by people who like your Page  \
# 244                                             51456
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 244                                               3316
#
#      comment    like  share  Total Interactions
# 244      372  5172.0  790.0                6334

# %% [markdown]
# ### ÐÐºÐ°Ð·Ð°Ð»Ð¾ÑÑ, ÑÑÐ¾ Ð½Ð°Ð¹Ð´ÐµÐ½Ð½ÑÐ¹ Ð¾Ð±ÑÐµÐºÑ Ð»Ð¸Ð´Ð¸ÑÑÐµÑ Ð¿Ð¾ Ð²ÑÐµÐ¼ ÑÐ°ÑÑÐ¼Ð°ÑÑÐ¸Ð²Ð°ÐµÐ¼ÑÐ¼ Ð¿Ð¾ÐºÐ°Ð·Ð°ÑÐµÐ»ÑÐ¼

# %%
df[(df['like'] == df['like'].max()) & (df['share'] == df['share'].max()) & (df['comment'] == df['comment'].max()) & (df['Total Interactions'] == df['Total Interactions'].max())]
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 244   1.0                     180480                           319133
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# 244                    8072                     4010
#
#      Lifetime Post Consumptions  \
# 244                        6242
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 244                                             108752
#
#      Lifetime Post reach by people who like your Page  \
# 244                                             51456
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 244                                               3316
#
#      comment    like  share  Total Interactions
# 244      372  5172.0  790.0                6334

# %% [markdown]
# ## ÐÐ¾ÑÐµÐ¼Ñ

# %% [markdown]
# ÐÐ¸Ð¿Ð¾ÑÐµÐ·Ð° â1: Ð¤Ð¾ÑÐ¾ Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½ÐµÐµ Ð´ÑÑÐ³Ð¸Ñ Ð²Ð¸Ð´Ð¾Ð² Ð¾Ð±ÑÐµÐºÑÐ¾Ð²

# %%
df.groupby(['Type'])[popular].mean()
# Out:
#           comment        like      share  Total Interactions
# Type
# Link     2.818182   73.318182  12.909091           89.045455
# Photo    7.492958  182.611765  27.158768          216.579812
# Status   8.911111  176.711111  31.422222          217.044444
# Video   12.285714  231.428571  52.142857          295.857143

# %% [markdown]
# ~~ÐÐ¸Ð¿Ð¾ÑÐµÐ·Ð° â1: Ð¤Ð¾ÑÐ¾ Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½ÐµÐµ Ð´ÑÑÐ³Ð¸Ñ Ð²Ð¸Ð´Ð¾Ð² Ð¾Ð±ÑÐµÐºÑÐ¾Ð²~~

# %% [markdown]
# ÐÐ¸Ð¿Ð¾ÑÐµÐ·Ð° â2: ÐÐ»Ð°ÑÐ½ÑÐµ Ð¾Ð±ÑÐµÐºÑÑ Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½ÐµÐµ Ð±ÐµÑÐ¿Ð»Ð°ÑÐ½ÑÑ

# %%
df.groupby(['Paid'])[popular].mean()
# Out:
#         comment        like      share  Total Interactions
# Paid
# 0.0    6.500000  155.846797  25.219101          186.852778
# 1.0   10.079137  235.647482  32.503597          278.230216

# %% [markdown]
# **ÐÐ¸Ð¿Ð¾ÑÐµÐ·Ð° â2: ÐÐ»Ð°ÑÐ½ÑÐµ Ð¾Ð±ÑÐµÐºÑÑ Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½ÐµÐµ Ð±ÐµÑÐ¿Ð»Ð°ÑÐ½ÑÑ**

# %% [markdown]
# ÐÐ¾ Ð¿Ð»Ð°ÑÐ½ÑÑ Ð¾Ð±ÑÐµÐºÑÐ¾Ð² Ð¼Ð½Ð¾Ð³Ð¾, Ð¿Ð¾ÑÐµÐ¼Ñ Ð¸Ð¼ÐµÐ½Ð½Ð¾ ÑÑÐ¾Ñ?

# %%
df['Paid'].value_counts()
# Out:
# 0.0    360
# 1.0    139
# Name: Paid, dtype: int64

# %% [markdown]
# ÐÐ¸Ð¿Ð¾ÑÐµÐ·Ð° â3: ÐÐ°ÑÐµÐ³Ð¾ÑÐ¸Ñ 2 Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½ÐµÐµ Ð¾ÑÑÐ°Ð»ÑÐ½ÑÑ

# %%
df.groupby(['Category'])[popular].mean()
# Out:
#             comment        like      share  Total Interactions
# Category
# 1          5.804651  124.887850  18.725118          148.488372
# 2         11.100000  218.707692  34.353846          264.161538
# 3          6.774194  217.012903  32.948387          256.735484

# %% [markdown]
# **ÐÐ¸Ð¿Ð¾ÑÐµÐ·Ð° â3: ÐÐ°ÑÐµÐ³Ð¾ÑÐ¸Ñ 2 Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½ÐµÐµ Ð¾ÑÑÐ°Ð»ÑÐ½ÑÑ**
#
# ÐÐ¾ ÐÐ°ÑÐµÐ³Ð¾ÑÐ¸Ñ 3 Ð±Ð»Ð¸Ð·ÐºÐ° Ð¿Ð¾ Ð±Ð¾Ð»ÑÑÐ¸Ð½ÑÑÐ²Ñ Ð¿Ð¾ÐºÐ°Ð·Ð°ÑÐµÐ»ÐµÐ¹

# %% [markdown]
# ÐÐ¸Ð¿Ð¾ÑÐµÐ·Ñ â2 Ð¸ â3 Ð²Ð¼ÐµÑÑÐµ

# %%
df.groupby(['Paid', 'Category'])[popular].agg(['mean', 'count'])
# Out:
#                  comment              like            share        \
#                     mean count        mean count       mean count
# Paid Category
# 0.0  1          5.496689   151  113.720000   150  18.727891   147
#      2          7.484536    97  152.422680    97  25.463918    97
#      3          7.000000   112  215.232143   112  33.526786   112
# 1.0  1          6.531250    64  151.062500    64  18.718750    64
#      2         22.406250    32  423.625000    32  61.500000    32
#      3          6.186047    43  221.651163    43  31.441860    43
#
#               Total Interactions
#                             mean count
# Paid Category
# 0.0  1                136.695364   151
#      2                185.371134    97
#      3                255.758929   112
# 1.0  1                176.312500    64
#      2                507.531250    32
#      3                259.279070    43

# %% [markdown]
# Ð Ð°ÑÑÐ¼Ð¾ÑÑÐ¸Ð¼ Ð¿Ð¾Ð´ÑÐ¾Ð±Ð½ÐµÐµ Ð½Ð°Ð¹Ð´ÐµÐ½Ð½ÑÐ¹ Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½ÑÐ¹ "ÑÐµÐ³Ð¼ÐµÐ½Ñ"

# %%
paid_category2 = df[(df['Paid'] == 1) & (df['Category'] == 2)].reset_index().copy()
paid_category2
# Out:
#     index  Page total likes    Type  Category  Post Month  Post Weekday  \
# 0       3            139441   Photo         2          12             2
# 1      14            138414   Photo         2          12             4
# 2      98            137020  Status         2          10             5
# 3     113            136642   Photo         2          10             1
# 4     142            136013  Status         2          10             3
# 5     152            135713   Photo         2          10             5
# 6     159            135617   Photo         2           9             1
# 7     165            135428   Photo         2           9             5
# 8     169            135428   Photo         2           9             3
# 9     175            135195  Status         2           9             6
# 10    180            134879  Status         2           9             4
# 11    193            133594   Photo         2           8             7
# ...

# %%
plt.boxplot(paid_category2['Total Interactions']);

# %%
plt.boxplot(paid_category2['comment']);

# %%
plt.boxplot(paid_category2['like']);

# %%
plt.boxplot(paid_category2['share']);

# %% [markdown]
# ---

# %% [markdown]
# **ÐÐ¸Ð´Ð½Ñ Ð½ÐµÑÐºÐ¾Ð»ÑÐºÐ¾ Ð²ÑÐ±ÑÐ¾ÑÐ¾Ð²**
#
# ÐÐµÑÐ¾ÑÑÐ½ÑÐµ Ð¿ÑÐ¸ÑÐ¸Ð½Ñ:
# 1. Ð²Ð¸ÑÑÑÐ½ÑÐ¹ ÑÑÑÐµÐºÑ
# 2. Ð¿Ð¾Ð¾ÑÑÐµÐ½Ð¸Ðµ Ð´ÐµÐ¹ÑÑÐ²Ð¸Ð¹ Ð¿Ð¾Ð»ÑÐ·Ð¾Ð²Ð°ÑÐµÐ»ÐµÐ¹, Ð½Ð°Ð¿ÑÐ¸Ð¼ÐµÑ ÐºÐ¾Ð½ÐºÑÑÑ Ñ Ð¿ÑÐ¸Ð·Ð°Ð¼Ð¸
#
# ÐÐ¸ÑÑÑÐ½ÑÐ¹ ÑÑÑÐµÐºÑ Ð±Ð¾Ð»ÐµÐµ Ð²ÐµÑÐ¾ÑÑÐµÐ½, Ñ.Ðº. Ð½Ð°Ð±Ð»ÑÐ´Ð°ÐµÑÑÑ Ð²ÑÐ±ÑÐ¾Ñ Ð¿Ð¾ Ð²ÑÐµÐ¼ Ð¿Ð¾ÐºÐ°Ð·Ð°ÑÐµÐ»ÑÐ¼. ÐÐ¾Ð¾ÑÑÐµÐ½Ð¸Ðµ Ð´ÐµÐ¹ÑÑÐ²Ð¸Ð¹ Ð¿Ð¾Ð»ÑÐ·Ð¾Ð²Ð°ÑÐµÐ»ÐµÐ¹ ÑÐºÐ¾ÑÐµÐµ Ð¿ÑÐ¸Ð²ÐµÐ´ÐµÑ Ðº Ð²ÑÐ±ÑÐ¾ÑÑ ÑÐ¾Ð»ÑÐºÐ¾ Ð¿Ð¾ Ð¿Ð¾Ð¾ÑÑÑÐµÐ¼Ð¾Ð¼Ñ Ð´ÐµÐ¹ÑÑÐ²Ð¸Ñ.

# %% [markdown]
# ÐÐµÐ· Ð°Ð½Ð¾Ð¼Ð°Ð»Ð¸Ð¹ Ð¿Ð¾ 'Total Interactions' Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½ÑÐ¹ ÑÐµÐ³Ð¼ÐµÐ½Ñ Ð¿ÑÐ¾Ð´Ð¾Ð»Ð¶Ð°ÐµÑ Ð»Ð¸Ð´Ð¸ÑÐ¾Ð²Ð°ÑÑ, Ð½Ð¾ ÑÐ¶Ðµ Ð±ÐµÐ· Ð´Ð²ÑÐºÑÐ°ÑÐ½Ð¾Ð³Ð¾ Ð¿ÑÐµÐ²ÑÑÐµÐ½Ð¸Ñ Ð²ÑÐµÑ Ð¿Ð¾ÐºÐ°Ð·Ð°ÑÐµÐ»ÐµÐ¹

# %%
df[df['Total Interactions']< 1000].groupby(['Paid', 'Category'])[popular].agg(['mean', 'count'])
# Out:
#                 comment              like            share        \
#                    mean count        mean count       mean count
# Paid Category
# 0.0  1         4.322148   149   97.844595   148  16.593103   145
#      2         7.291667    96  138.333333    96  24.739583    96
#      3         5.000000   108  170.314815   108  30.583333   108
# 1.0  1         6.531250    64  151.062500    64  18.718750    64
#      2         7.827586    29  205.275862    29  32.448276    29
#      3         4.536585    41  158.195122    41  27.463415    41
#
#               Total Interactions
#                             mean count
# Paid Category
# 0.0  1                117.657718   149
#      2                170.364583    96
#      3                205.898148   108
# 1.0  1                176.312500    64
#      2                245.551724    29
#      3                190.195122    41

# %% [markdown]
# ÐÑÑÑ Ð°Ð½Ð¾Ð¼Ð°Ð»Ð¸Ð¸ Ð¸ Ð² Ð´ÑÑÐ³Ð¸Ñ ÑÐµÐ³Ð¼ÐµÐ½ÑÐ°Ñ

# %%
df[df['Total Interactions']> 1000].groupby(['Paid', 'Category'])[popular].agg(['mean', 'count'])
# Out:
#                   comment               like             share        \
#                      mean count         mean count        mean count
# Paid Category
# 0.0  1          93.000000     2  1288.500000     2  173.500000     2
#      2          26.000000     1  1505.000000     1   95.000000     1
#      3          61.000000     4  1428.000000     4  113.000000     4
# 1.0  2         163.333333     3  2534.333333     3  342.333333     3
#      3          40.000000     2  1522.500000     2  113.000000     2
#
#               Total Interactions
#                             mean count
# Paid Category
# 0.0  1                    1555.0     2
#      2                    1626.0     1
#      3                    1602.0     4
# 1.0  2                    3040.0     3
#      3                    1675.5     2

# %% [markdown]
# # ÐÑÐ²Ð¾Ð´ #
#
# **ÐÑÑÐ¾Ð´Ð½ÑÐµ Ð¿Ð°ÑÐ°Ð¼ÐµÑÑÑ (ÐºÐ°ÑÐµÐ³Ð¾ÑÐ¸Ñ, Ð¿Ð»Ð°ÑÐ½Ð¾ÑÑÑ Ð¸ Ñ.Ð´.) Ð²Ð»Ð¸ÑÑÑ Ð½Ð° Ð¿Ð¾ÐºÐ°Ð·Ð°ÑÐµÐ»Ð¸ Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½Ð¾ÑÑÐ¸, Ð½Ð¾ Ð½Ðµ Ð¾Ð±ÑÑÑÐ½ÑÑÑ Ð²ÑÐ´Ð°ÑÑÐ¸ÐµÑÑ Ð¿Ð¾ÐºÐ°Ð·Ð°ÑÐµÐ»Ð¸.
# ÐÑÐ´ÐµÐ»ÑÑÑÐ°ÑÑÑ Ð¿Ð¾Ð¿ÑÐ»ÑÑÐ½Ð¾ÑÑÑ Ð¾ÑÐ´ÐµÐ»ÑÐ½ÑÑ Ð¾Ð±ÑÐµÐºÑÐ¾Ð² Ð¾Ð±ÑÑÑÐ½ÑÐµÑÑÑ Ð»Ð¸Ð±Ð¾ Ð¿Ð¾Ð¾ÑÑÐµÐ½Ð¸ÐµÐ¼ Ð°ÐºÑÐ¸Ð²Ð½Ð¾ÑÑÐ¸ Ð¿Ð¾Ð»ÑÐ·Ð¾Ð²Ð°ÑÐµÐ»ÐµÐ¹, Ð»Ð¸Ð±Ð¾, ÑÐºÐ¾ÑÐµÐµ Ð²ÑÐµÐ³Ð¾, Ð²Ð¸ÑÑÑÐ½ÑÐ¼ ÑÑÑÐµÐºÑÐ¾Ð¼ - Ð¿ÑÐ¸ÑÐ¸Ð½Ð° ÐºÐ¾ÑÐ¾ÑÐ¾Ð³Ð¾ Ð² ÑÐ°Ð¼Ð¾Ð¼ ÐºÐ¾Ð½ÑÐµÐ½ÑÐµ, Ð° Ð½Ðµ Ð² Ð¿Ð°ÑÐ°Ð¼ÐµÑÑÐ°Ñ ÐµÐ³Ð¾ Ð¿ÑÐ±Ð»Ð¸ÐºÐ°ÑÐ¸Ð¸.**
